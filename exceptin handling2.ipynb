# %%
try:
    age=int(input("Enter the age"))
except ValueError:
    print("enter the valid age or around age")
# Out:
# Enter the age 19.6
# enter the valid age or around age

# %%
try:
    marks=int(input("Enter the marks"))
except ValueError:
    print("enter the valid marks")
# Out:
# Enter the marks 0
