# %%
import pandas as pd
data={
      "Name":["mokshuu","rachna","varshu","navya"],
      "Age":[19,20,26,30],
      "City":["knr","jgtl","kpl","vmd"]
}
details=pd.DataFrame(data)
print(details)
# Out:
#       Name  Age  City
# 0  mokshuu   19   knr
# 1   rachna   20  jgtl
# 2   varshu   26   kpl
# 3    navya   30   vmd

# %%
import pandas as pd
data={
      "Name":["mokshuu","rachna","varshu","navya"],
      "Age":[19,20,26,30],
      "City":["knr","jgtl","kpl","vmd"]
}
details=pd.DataFrame(data)
print(details.shape)
# Out:
# (4, 3)

# %%
import pandas as pd
data={
      "Name":["mokshuu","rachna","varshu","navya"],
      "Age":[19,20,26,30],
      "City":["knr","jgtl","kpl","vmd"]
}
details=pd.DataFrame(data)
print(details.columns)
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')

# %%
import pandas as pd
data={
      "Name":["mokshuu","rachna","varshu","navya"],
      "Age":[19,20,26,30],
      "City":["knr","jgtl","kpl","vmd"]
}
details=pd.DataFrame(data)
print(details.index)
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
import pandas as pd
data={
      "Name":["mokshuu","rachna","varshu","navya","roshni","apple","banana"],
      "Age":[19,20,26,30,45,39,25],
      "City":["knr","jgtl","kpl","vmd","ngl","wrgl","nzb"]
}
details=pd.DataFrame(data)
print(details.head())           #head method shows only top 5 results
# Out:
#       Name  Age  City
# 0  mokshuu   19   knr
# 1   rachna   20  jgtl
# 2   varshu   26   kpl
# 3    navya   30   vmd
# 4   roshni   45   ngl

# %%
import pandas as pd
data={
      "Name":["mokshuu","rachna","varshu","navya","roshni","apple","prvlika"],
      "Age":[19,20,26,30,45,39,25],
      "City":["knr","jgtl","kpl","vmd","ngl","wrgl","nzb"]
}
details=pd.DataFrame(data)
print(details.tail())          #tail method shows only last 5 results
# Out:
#       Name  Age  City
# 2   varshu   26   kpl
# 3    navya   30   vmd
# 4   roshni   45   ngl
# 5    apple   39  wrgl
# 6  prvlika   25   nzb

# %%
import pandas as pd
data={
      "Name":["mokshuu","rachna","varshu","navya","roshni","apple","prvlika"],
      "Age":[19,20,26,30,45,39,25],
      "City":["knr","jgtl","kpl","vmd","ngl","wrgl","nzb"]
}
details=pd.DataFrame(data)
print(details.sample(3))        #sample it will gives the random one
# Out:
#       Name  Age  City
# 6  prvlika   25   nzb
# 3    navya   30   vmd
# 1   rachna   20  jgtl

# %%
import pandas as pd
data={
      "Name":["mokshuu","rachna","varshu","navya","roshni","apple","banana"],
      "Age":[19,20,26,30,45,39,25],
      "City":["knr","jgtl","kpl","vmd","ngl","wrgl","nzb"]
}
details=pd.DataFrame(data)
print(details.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Age     7 non-null      int64
#  2   City    7 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 300.0+ bytes
# None

# %%
import pandas as pd
data={
      "Name":["mokshuu","rachna","varshu","navya","roshni","apple","banana"],
      "Age":[19,20,26,30,45,39,25],
      "City":["knr","jgtl","kpl","vmd","ngl","wrgl","nzb"]
}
details=pd.DataFrame(data)
print(details.describe())             #describe all the age and tell about the count
# Out:
#              Age
# count   7.000000
# mean   29.142857
# std     9.685532
# min    19.000000
# 25%    22.500000
# 50%    26.000000
# 75%    34.500000
# max    45.000000

# %%
import pandas as pd
data={
      "Name":["mokshuu","rachna","varshu","navya","roshni","apple","banana"],
      "Age":[19,20,26,30,45,39,25],
      "City":["knr","jgtl","kpl","vmd","ngl","wrgl","nzb"]
}
details=pd.DataFrame(data)   
print(details["Name"])
# Out:
# 0    mokshuu
# 1     rachna
# 2     varshu
# 3      navya
# 4     roshni
# 5      apple
# 6     banana
# Name: Name, dtype: object

# %%
import pandas as pd
data={
      "Name":["mokshuu","rachna","varshu","navya","roshni","apple","banana"],
      "Age":[19,20,26,30,45,39,25],
      "City":["knr","jgtl","kpl","vmd","ngl","wrgl","nzb"]
}
details=pd.DataFrame(data)   
print(details["Age"])
# Out:
# 0    19
# 1    20
# 2    26
# 3    30
# 4    45
# 5    39
# 6    25
# Name: Age, dtype: int64

# %%
data={
      "Name":["mokshuu","rachna","varshu","navya","roshni","apple","banana"],
      "Age":[19,20,26,30,45,39,25],
      "City":["knr","jgtl","kpl","vmd","ngl","wrgl","nzb"]
}
details=pd.DataFrame(data)   
print(details.iloc[2])
# Out:
# Name    varshu
# Age         26
# City       kpl
# Name: 2, dtype: object

# %%
data={
      "Name":["mokshuu","rachna","varshu","navya","roshni","apple","banana"],
      "Age":[19,20,26,30,45,39,25],
      "City":["knr","jgtl","kpl","vmd","ngl","wrgl","nzb"]
}
details=pd.DataFrame(data)   
print(details.loc[[0,1,2,3]])
# Out:
#       Name  Age  City
# 0  mokshuu   19   knr
# 1   rachna   20  jgtl
# 2   varshu   26   kpl
# 3    navya   30   vmd
