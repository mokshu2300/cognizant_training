# %%
import numpy as np
arr=np.array([10,20,30,40])
print(arr)
# Out:
# [10 20 30 40]

# %%
import numpy as np
food=np.array(["biryani,noodles,maggie"])
print(food)
# Out:
# ['biryani,noodles,maggie']

# %%
import numpy as np
arr=np.array([[10,20],[30,40],[50,60]])
print(arr)
# Out:
# [[10 20]
#  [30 40]
#  [50 60]]

# %%
flower=np.array([["daisy,rose"],["lilly,lotus"],["jasmine,gold"]])
print(flower)
# Out:
# [['daisy,rose']
#  ['lilly,lotus']
#  ['jasmine,gold']]

# %%
a=np.array([10,20,30,40])
b=np.array([1,2,3,4])
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# [11 22 33 44]
# [ 9 18 27 36]
# [ 10  40  90 160]
# [10. 10. 10. 10.]

# %%
abc=np.array([10,20,30,40])
print(np.max(abc))
# Out:
# 40

# %%
abc=np.array([10,20,30,40])
print(np.min(abc))
# Out:
# 10

# %%
abc=np.array([10,20,30,40])
print(np.mean(abc))
# Out:
# 25.0

# %%
a=np.array([10,20,30,40])
print(np.sum(abc))
# Out:
# 100

# %%
a=np.array([10,20,30,40])
print(np.average(abc))
# Out:
# 25.0
