# %%
name=["mokshu","navya","pravalika","varshu"]
print(name)
# Out:
# ['mokshu', 'navya', 'pravalika', 'varshu']

# %%
name=["mokshu","navya","varshu"]
it=iter(name)
print(next(it))
print(next(it))
print(next(it))
# Out:
# mokshu
# navya
# varshu

# %%
numeric=[1,2,3,4,5]
it=iter(numeric)
print(next(it))
print(next(it))
print(next(it))
print(next(it))
print(next(it))
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
chocos=["dairy milk","munch","five star"]
it=iter(chocos)
print(next(it))
print(next(it))
print(next(it))
# Out:
# dairy milk
# munch
# five star

# %%
def numbers():
    yield 1
    yield 2
    yield 3
gen = numbers()
print(next(gen))
print(next(gen))
print(next(gen))
# Out:
# 1
# 2
# 3
