# %%
import numpy as np
arr=np.arange(10)
print(arr[::2])
print(arr[1:7:2])
# Out:
# [0 2 4 6 8]
# [1 3 5]

# %%
arr=np.arange(10)
print(np.split(arr, 2))     #splits into 2 parts
# Out:
# [array([0, 1, 2, 3, 4]), array([5, 6, 7, 8, 9])]
