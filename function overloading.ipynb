# %%
name="mokshitha"
def greet():
    print("Hello", name)
greet()
# Out:
# Hello mokshitha

# %%
fruit="mango"
def eat():
    print("Iam hungry to eat", fruit)
eat()
# Out:
# Iam hungry to eat mango

# %%
game="subway surf"
def play():
    print("I like to play", game)
play()
# Out:
# I like to play subway surf

# %%
def add(a,b):
    return a+b
print(add(30,400))
# Out:
# 430

# %%
def add(a,b,c=0):
    return a+b+c
print(add(690,989))
print(add(690,989,776))
# Out:
# 1679
# 2455

# %%
def multiplication(a,b,c=0):
    return a*b*c
print(multiplication(987,789,887))
print(multiplication(987,789))
# Out:
# 690745041
# 0

# %%
def subtraction(a,b,c=0):
    return a-b-c
print(subtraction(1900,980,222))
print(subtraction(230,678))
# Out:
# 698
# -448

# %%
def add (*numbers):
    print(sum(numbers))
add(399,799)
add(399,799,699)
add(399,799,699,399)
# Out:
# 1198
# 1897
# 2296

# %%
def add(*numbers):
    print(sum(numbers))
add(10,20)
add(10,20,30)
add(10,20,30,40)
add(10,20,30,40,50)
# Out:
# 30
# 60
# 100
# 150

# %%
def addstudent(*marks):
    print(sum(marks))
add(389,999)
add(3783,4949)
# Out:
# 1388
# 8732

# %%
def student (*marks):
    print(sum(marks))
student(899,799,450)
student(2000,4339,29203)
student(289,2839,2038)
# Out:
# 2148
# 35542
# 5166
