# %%
import pandas as pd
data={
    "Date":["2007-01-23","1981-12-07","2004-08-21","2026-12-07","2026-07-15"]
}
result=pd.DataFrame(data)
result["Date"]=pd.to_datetime(result["Date"])
print(result)
# Out:
#         Date
# 0 2007-01-23
# 1 1981-12-07
# 2 2004-08-21
# 3 2026-12-07
# 4 2026-07-15

# %%
result["Date"].dt.year
# Out:
# 0    2007
# 1    1981
# 2    2004
# 3    2026
# 4    2026
# Name: Date, dtype: int32

# %%
result["Date"].dt.month
# Out:
# 0     1
# 1    12
# 2     8
# 3    12
# 4     7
# Name: Date, dtype: int32

# %%
result["Date"].dt.day_name()
# Out:
# 0      Tuesday
# 1       Monday
# 2     Saturday
# 3       Monday
# 4    Wednesday
# Name: Date, dtype: object

# %%
pd.Timestamp.now()
# Out:
# Timestamp('2026-06-18 16:24:55.445370')

# %%
from datetime import datetime
date1=datetime(2007,1,23)
date2=datetime(2006,4,24)
print(date2-date1)
# Out:
# -274 days, 0:00:00
