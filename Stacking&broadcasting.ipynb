# %%
import numpy as np
a=np.array([1,2,3,4])
b=np.array([5,6,7,8])
c=np.vstack((a,b))
print(c)
# Out:
# [[1 2 3 4]
#  [5 6 7 8]]

# %%
import numpy as np
a=np.array([1,2,3,4])
b=np.array([5,6,7,8])
c=np.hstack((a,b))
print(c)
# Out:
# [1 2 3 4 5 6 7 8]

# %%
import numpy as np
a=np.array([1,2,3,4])
b=np.array([5,6,7,8])
print(np.hstack((a,b)))
# Out:
# [1 2 3 4 5 6 7 8]

# %%
arr=np.array([2,3,4,5,6])
print(arr+5)
# Out:
# [ 7  8  9 10 11]

# %%
arr=np.array(["a","m","s","k","v"])
print(arr+"n")
# Out:
# ['an' 'mn' 'sn' 'kn' 'vn']

# %%
arr=np.array([[2,3],[5,6]])
print(arr+[5,7])
# Out:
# [[ 7 10]
#  [10 13]]

# %%
arr=np.array([[6,8,0],[6,2,3]])
print(arr+[3,4,1])
# Out:
# [[ 9 12  1]
#  [ 9  6  4]]
