# %%
class Car:
    name= "Swift"
    color= "Yellow"

car1=Car   
print(car1.name)
print(car1.color)
# Out:
# Swift
# Yellow

# %%
class MySchool:
    name= "Ghs"
    place= "Mmkt"

myschool1=MySchool
print(myschool1.name)
print(myschool1.place)
# Out:
# Ghs
# Mmkt

# %%
class Student:
    def __init__(self,name,age):
        self.name=name
        self.age=age

s1=Student("Mokshu",19)
print(s1.name)
print(s1.age)
# Out:
# Mokshu
# 19

# %%
class Car:
    colour="Red"
    brand="BMW"
    speed=120
    
car1=Car()
print(car1.colour)
print(car1.brand)
# Out:
# Red
# BMW
