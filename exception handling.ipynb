# %%
values=[1,2,3,4,5]
print(values[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 2
#       1 values=[1,2,3,4,5]
# ----> 2 print(values[5])
#
# IndexError: list index out of range

# %%
values=[1,2,3,4,5]
print(values[4])
# Out:
# 5

# %%
try:
    num=10
    print(num/0)
except ZeroDivisionError:
    print("cannot divide by zero")
# Out:
# cannot divide by zero

# %%
file = open("demo txt","w")
file.write

# %%
try:
    file = open("xyz.txt","r")
except FileNotFoundError:
    print("file doesn't exist")
# Out:
# file doesn't exist

# %%
try:
    age=int(input("Enter the age"))
except ValueError:
    print("enter the valid age or around age")
# Out:
# Enter the age 19
