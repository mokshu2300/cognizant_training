# %%
try:
    num=int(input("Enter the Number"))
    print(10/num)
except ZeroDivisionError:
    print("the number is zero")
except ValueError:
    print("The character")
# Out:
# Enter the Number 0
# the number is zero

# %%
try:
    num=int(input("Enter the Number"))
    print(10/num)
except ZeroDivisionError:
    print("the number is zero")
except ValueError:
    print("The character")
# Out:
# Enter the Number mokshitha
# The character

# %%
try:
    num=int(input("Enter the Number"))
    print(10/num)
except ZeroDivisionError:
    print("the number is zero")
except ValueError:
    print("The character")
# Out:
# Enter the Number 17
# 0.5882352941176471
